# %% [markdown]
# # Regressão Polinomial Com Descida de Gradiente
#
# Nos notebooks [Regressão Linear Simples com Descida de Gradiente](https://nbviewer.jupyter.org/github/yurimalheiros/ai-notebooks/blob/master/ml/gdlinearregression.ipynb) e [Regressão Linear Múltipla com Descida de Gradiente](https://nbviewer.jupyter.org/github/yurimalheiros/ai-notebooks/blob/master/ml/gdmultiplelinearregression.ipynb) foi mostrado como ajustar funções lineares a um conjunto de dados para realizar previsões.
#
# Em ambos os casos, uma função só se adequava bem aos dados de treinamento se eles seguissem uma tendência linear.
# Entretanto, para dados que não seguiam essa tendência, a função não se adequava bem, o que acabaria gerando previsões ruins. Assim, para dados não lineares é possível ajustar outros tipos de funções que não sejam lineares através da Regressão Polinomial, gerando curvas ou superfícies mais complexas.

# %% [markdown]
# Continuaremos utilizando o exemplo dos preços das casas de acordo com o seu tamanho. Abaixo temos o gráfico representando esses dados.

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
output_notebook()

sizes = [0.998, 1.500, 1.175, 1.232, 1.121, 0.988, 1.240, 1.501, 1.225, 1.552, 0.975, 1.121, 1.020,
        1.501, 1.664, 1.488, 1.376, 1.500, 1.256, 1.690, 1.820, 1.652, 1.777, 1.504, 1.831, 1.200 ]

prices = [25.9, 29.5, 27.9, 25.9, 29.9, 29.9, 30.9, 28.9, 35.9, 31.5, 31.0, 30.9, 30.0, 28.9, 36.9,
          41.9, 40.5, 43.9, 37.5, 37.9, 44.5, 37.9, 38.9, 36.9, 45.8, 41.0]

p = figure(plot_width=700, plot_height=250)
p.circle(sizes, prices)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2544b2a7-b64d-4991-a4b7-efe9de7d7889">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="833490e2-36a7-4ca1-bb78-a36a1e558152"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("833490e2-36a7-4ca1-bb78-a36a1e558152");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("7757b320-bb8c-42cb-bc52-fed251f93448", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("833490e2-36a7-4ca1-bb78-a36a1e558152");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '833490e2-36a7-4ca1-bb78-a36a1e558152' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"374902f6-420b-46a6-ab3c-dd38009029ac":{"roots":{"references":[{"attributes":{},"id":"f6242fde-9acc-4d1c-8bc7-f4f8bc80e80d","type":"BasicTickFormatter"},{"attributes":{},"id":"2ff2e70d-11c9-44e8-a614-b839f2d11753","type":"LinearScale"},{"attributes":{},"id":"e0179119-351c-4c3d-8a2f-872ec633ec66","type":"LinearScale"},{"attributes":{"formatter":{"id":"f6242fde-9acc-4d1c-8bc7-f4f8bc80e80d","type":"BasicTickFormatter"},"plot":{"id":"59d33a2f-5725-42f7-a1b7-f0b8dacc5c45","subtype":"Figure","type":"Plot"},"ticker":{"id":"136fb5a3-2559-4ec0-9c01-2ea779edf932","type":"BasicTicker"}},"id":"49dc6671-5652-4515-9bed-9f8d5fda8b27","type":"LinearAxis"},{"attributes":{},"id":"136fb5a3-2559-4ec0-9c01-2ea779edf932","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5bb54af2-c953-409e-bf45-d94b7575c2e2","type":"Circle"},{"attributes":{"plot":{"id":"59d33a2f-5725-42f7-a1b7-f0b8dacc5c45","subtype":"Figure","type":"Plot"},"ticker":{"id":"136fb5a3-2559-4ec0-9c01-2ea779edf932","type":"BasicTicker"}},"id":"cff885d2-59ad-4c19-8ccb-57b5f5e94485","type":"Grid"},{"attributes":{"formatter":{"id":"175d3402-6931-4df1-9206-0e02e6b094b1","type":"BasicTickFormatter"},"plot":{"id":"59d33a2f-5725-42f7-a1b7-f0b8dacc5c45","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d24288e-d767-4123-b5d4-0baff51a9e54","type":"BasicTicker"}},"id":"9de63a91-21e0-4db5-8a4d-7ea430c741a0","type":"LinearAxis"},{"attributes":{},"id":"2d24288e-d767-4123-b5d4-0baff51a9e54","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"59d33a2f-5725-42f7-a1b7-f0b8dacc5c45","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d24288e-d767-4123-b5d4-0baff51a9e54","type":"BasicTicker"}},"id":"5b0acac2-2bff-4416-aeee-5e259e6608bd","type":"Grid"},{"attributes":{"data_source":{"id":"9db1c319-ac0a-48d9-9164-979411e63f25","type":"ColumnDataSource"},"glyph":{"id":"7135f8f4-b0b6-4898-989b-a0ee2beca129","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5bb54af2-c953-409e-bf45-d94b7575c2e2","type":"Circle"},"selection_glyph":null},"id":"a6f4aa6b-6809-4c98-a72a-e3ca048aef44","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4361e4de-4d5c-4fa0-b1db-dbf2ed0c44ed","type":"PanTool"},{"id":"0f61aa18-a085-4dcd-9ddb-8fd8db73d86e","type":"WheelZoomTool"},{"id":"a8218e54-47c6-41b5-bf54-a60d151d8e07","type":"BoxZoomTool"},{"id":"71bea1cf-aef0-4625-8fad-735ff50c23ea","type":"SaveTool"},{"id":"9a592a5d-67fb-426f-9381-f04be824d873","type":"ResetTool"},{"id":"4f3f8af1-4414-409d-90a1-2a3240e6849e","type":"HelpTool"}]},"id":"ad8e4ef1-6252-44e8-a384-f67362d86a0a","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8d6b846a-f157-46c6-91d7-81365620afde","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"a8fbbf26-9074-4e2f-92bf-db1114bae3f9","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.998,1.5,1.175,1.232,1.121,0.988,1.24,1.501,1.225,1.552,0.975,1.121,1.02,1.501,1.664,1.488,1.376,1.5,1.256,1.69,1.82,1.652,1.777,1.504,1.831,1.2],"y":[25.9,29.5,27.9,25.9,29.9,29.9,30.9,28.9,35.9,31.5,31.0,30.9,30.0,28.9,36.9,41.9,40.5,43.9,37.5,37.9,44.5,37.9,38.9,36.9,45.8,41.0]}},"id":"9db1c319-ac0a-48d9-9164-979411e63f25","type":"ColumnDataSource"},{"attributes":{},"id":"175d3402-6931-4df1-9206-0e02e6b094b1","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"49dc6671-5652-4515-9bed-9f8d5fda8b27","type":"LinearAxis"}],"left":[{"id":"9de63a91-21e0-4db5-8a4d-7ea430c741a0","type":"Lin ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1]</strong>&gt;</code></p>

# %% [markdown]
# A Regressão Polinomial funciona de maneira muito parecida com a regressão linear, a principal diferença é o tipo da função que é gerada. A regressão linear gera retas ou superfícies representadas por funções do tipo: $f(x) = w_0x_0 + w_1x_1 + ... + x_2x_n$. Por outro lado, a Regressão Polinomial pode gerar curvas e superfícies dos mais variados tipos, por exemplo: $f(x) = w_0x_0 + w_1x_1^2$ ou $f(x) = w_0 + w_1x_1 + w_2x_2^3$.
#
# Vamos fazer um exemplo tentando ajustar uma função do tipo: $f(x) = w_0 + w_1x^2$ aos dados de treinamento.
#
# O código abaixo recebe os valores de x, $w_0$ e $w_1$ e calcula o resultado da função.

# %%
def f(x, w0, w1):
    return w1*(x**2) + w0

# %% [markdown]
# A função de erro médio quadrático continua a mesma. Ela é calculada através do código abaixo:

# %%
def square_error(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)**2

        total += error

    return total/(2*len(X))

# %% [markdown]
# Mais uma vez utilizaremos a descida de gradiente para encontrar a função que melhor se ajusta aos dados de treinamento. Com isso, durante o algoritmo, será necessário calcular as derivadas da função de erro médio quadrático.
#
# O código abaixo calcula a derivada parcial em relação a $w_0$

# %%
def d_error_w0(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)

        total += error

    return total/(len(X))

# %% [markdown]
# E a função abaixo calcula a derivada parcial em relação a $w_1$

# %%
def d_error_w1(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)

        total += error*x**2

    return total/(len(X))

# %% [markdown]
# Com a função e as derivadas parciais em mãos, aplicaremos o algoritmo de descida de gradiente.
# No código abaixo, os pesos são atualizados 1000 vezes.

# %%
w = [0, 0]
learning_rate = 0.1

for i in range(1000):        
    w0i = w[0] - learning_rate*d_error_w0(sizes, prices, w[0], w[1])
    w1i = w[1] - learning_rate*d_error_w1(sizes, prices, w[0], w[1])

    w[0] = w0i
    w[1] = w1i

print("Função gerada: {} + {}x^2".format(w[0], w[1]))
# Out:
# Função gerada: 24.615774400324003 + 5.070623894139969x^2

# %% [markdown]
# No gráfico a seguir observarmos que a curva encontrada não é mais uma reta.

# %%
import numpy as np

x_points = np.linspace(0, 3, 50)
y_points = [f(i, w[0], w[1]) for i in x_points]

p = figure(plot_width=700, plot_height=250)
p.scatter(sizes, prices, radius=0.03, alpha=0.5)
p.line(x_points, y_points, line_width=2)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1a1ed2b6-a8f6-4210-bef3-fa83afcb4493"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1a1ed2b6-a8f6-4210-bef3-fa83afcb4493");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("5fa6366f-14d8-4389-8159-940704cd38eb", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a1ed2b6-a8f6-4210-bef3-fa83afcb4493");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a1ed2b6-a8f6-4210-bef3-fa83afcb4493' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"77f4e948-e6a2-4304-b541-ae8ed1db27a9":{"roots":{"references":[{"attributes":{"overlay":{"id":"b3c7a1fd-7cb8-47b5-98c6-797fe24637b5","type":"BoxAnnotation"},"plot":{"id":"437edcd4-1206-432d-9f95-e13dd3aee2ab","subtype":"Figure","type":"Plot"}},"id":"93f999ef-d23a-4759-a1d7-6c140fda71d1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"437edcd4-1206-432d-9f95-e13dd3aee2ab","subtype":"Figure","type":"Plot"}},"id":"67b2ef54-bdbb-497f-a14a-bd831b076c5c","type":"SaveTool"},{"attributes":{"plot":{"id":"437edcd4-1206-432d-9f95-e13dd3aee2ab","subtype":"Figure","type":"Plot"}},"id":"fd959bb4-aa06-4a2c-ad75-dab613095016","type":"ResetTool"},{"attributes":{"plot":{"id":"437edcd4-1206-432d-9f95-e13dd3aee2ab","subtype":"Figure","type":"Plot"}},"id":"995c1f47-f58d-4b82-9460-e55752381d1e","type":"HelpTool"},{"attributes":{},"id":"5b2785a5-ac3e-44ba-92a9-1e73453e2aff","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"fcd0f6e9-a632-4aa2-90de-f2498e661c4e","type":"ColumnDataSource"},"glyph":{"id":"2b99572b-bdea-4687-be9a-f22a5b4e8a8c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2d869f97-2799-4cde-97c2-1b1db1e642fe","type":"Line"},"selection_glyph":null},"id":"519ee9e2-9c36-49d6-8612-0f378428c526","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"4ab053a2-8bd3-45b7-85a7-5b0cafe0632c","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b3c7a1fd-7cb8-47b5-98c6-797fe24637b5","type":"BoxAnnotation"},{"attributes":{},"id":"10c4ba6c-a1e4-412c-b20c-f9175fee3c80","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2b99572b-bdea-4687-be9a-f22a5b4e8a8c","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.998,1.5,1.175,1.232,1.121,0.988,1.24,1.501,1.225,1.552,0.975,1.121,1.02,1.501,1.664,1.488,1.376,1.5,1.256,1.69,1.82,1.652,1.777,1.504,1.831,1.2],"y":[25.9,29.5,27.9,25.9,29.9,29.9,30.9,28.9,35.9,31.5,31.0,30.9,30.0,28.9,36.9,41.9,40.5,43.9,37.5,37.9,44.5,37.9,38.9,36.9,45.8,41.0]}},"id":"0dfe6080-ae84-41f2-88df-869f0aa04fc8","type":"ColumnDataSource"},{"attributes":{},"id":"4915532a-a871-4634-bd40-204379615eb4","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"c81c576c-dad0-4d09-9775-6060afd2dd7c","type":"DataRange1d"},{"attributes":{"below":[{"id":"ad909bd4-7206-4fdb-9702-82b4d16f1c41","type":"LinearAxis"}],"left":[{"id":"0a06c93c-15e6-46ac-a716-e904b5de2cfd","type":"LinearAxis"}],"plot_height":250,"plot_width":700,"renderers":[{"id":"ad909bd4-7206-4fdb-9702-82b4d16f1c41","type":"LinearAxis"},{"id":"4e95d980-5101-4a75-8959-555a3998533a","type":"Grid"},{"id":"0a06c93c-15e6-46ac-a716-e904b5de2cfd","type":"LinearAxis"},{"id":"238c38e0-a5e0-42ef-bc7f-732820e8bbe4","type":"Grid"},{"id":"b3c7a1fd-7cb8-47b5-98c6-797fe24637b5","type":"BoxAnnotation"},{"id":"bb443e73-96a5-4b33-b20a-b1ee8496a1cf","type":"GlyphRenderer"},{"id":"519ee9e2-9c36-49d6-8612-0f378428c526","type":"GlyphRenderer"}],"title":{"id":"4ab053a2-8bd3-45b7-85a7-5b0cafe0632c","type":"Title"},"tool_events":{"id":"10c4ba6c-a1e4-412c-b20c-f9175fee3c80","type":"ToolEvents"},"toolbar":{"id":"b8180f87-728c-444d-8910-63b858de90a8","type":"Toolbar"},"x_range":{"id":"c81c576c-dad0-4d09-9775-6060afd2dd7c","type":"DataRange1d"},"x_scale":{"id":"c9ef2aa9-1816-4003-9ba3-66b502188fdf","type":"LinearScale"},"y_range":{"id":"eed64bca-fcbc-47bb-b1d7-18432757b169","type":"DataRange1d"},"y_scale":{"id":"93c67006-f85d-4cc2-80c7-e769b9a98997","type":"LinearScale"}},"id":"437edcd4-1206-432d-9f95-e13dd3aee2ab","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","ac ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# Vamos fazer um segundo exemplo, agora tentando ajustar a função: $f(x) = w_3x^3 + w_2x^2 + w_1x + w_0$

# %%
def f(x, w0, w1, w2, w3):
    return w3*(x**3) + w2*(x**2) + w1*x + w0

# %% [markdown]
# Nesse exemplo, precisamos calcular quatro derivadas parciais, pois temos 4 coeficientes ($w_0, w_1, w_2, w_3$)

# %%
def d_error_w0(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error

    return total/(len(X))

def d_error_w1(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x

    return total/(len(X))

def d_error_w2(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x**2

    return total/(len(X))

def d_error_w3(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x**3

    return total/(len(X))

# %% [markdown]
# Por fim, realizando a descida de gradiente, encontramos os coeficientes.

# %%
w = [0, 0, 0, 0]
learning_rate = 0.1

for i in range(1000):        
    w0i = w[0] - learning_rate*d_error_w0(sizes, prices, w[0], w[1], w[2], w[3])
    w1i = w[1] - learning_rate*d_error_w1(sizes, prices, w[0], w[1], w[2], w[3])
    w2i = w[2] - learning_rate*d_error_w2(sizes, prices, w[0], w[1], w[2], w[3])
    w3i = w[3] - learning_rate*d_error_w3(sizes, prices, w[0], w[1], w[2], w[3])

    w[0] = w0i
    w[1] = w1i
    w[2] = w2i
    w[3] = w3i
    
print("Função gerada: {} + {}x^2 + {}x^3 + {}x^4".format(w[0], w[1], w[2], w[3]))
# Out:
# Função gerada: 15.796264315235701 + 10.422723031103592x^2 + 3.89992652251128x^3 + -1.1240198966981076x^4

# %%
x_points = np.linspace(0, 3, 50)
y_points = [f(i, w[0], w[1], w[2], w[3]) for i in x_points]

p = figure(plot_width=700, plot_height=250)
p.scatter(sizes, prices, radius=0.03, alpha=0.5)
p.line(x_points, y_points, line_width=2)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="18acdbf3-e3c2-4999-9a6e-ffb7a8c42ebd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("18acdbf3-e3c2-4999-9a6e-ffb7a8c42ebd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("70a8b723-eee6-431c-9c6f-4bba28a5bac4", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("18acdbf3-e3c2-4999-9a6e-ffb7a8c42ebd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '18acdbf3-e3c2-4999-9a6e-ffb7a8c42ebd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cc373421-bda9-4b0a-be4c-6bf991079d76":{"roots":{"references":[{"attributes":{},"id":"3ab36c47-aae9-403c-a490-a450e280802c","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"97668622-2db1-4487-9de6-dfef719caf3d","type":"ColumnDataSource"},"glyph":{"id":"7921c7c1-0cba-4b70-94e8-e7f34a604059","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"94062e56-0f40-4bad-b718-eb19e67b21f5","type":"Line"},"selection_glyph":null},"id":"ca0e0422-0612-46e9-8b94-8a4eb0517100","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ffeac33d-7811-4339-b4b9-559f912ef721","subtype":"Figure","type":"Plot"}},"id":"15c0ac18-5025-42a5-aa47-bfe33d147087","type":"PanTool"},{"attributes":{"plot":{"id":"ffeac33d-7811-4339-b4b9-559f912ef721","subtype":"Figure","type":"Plot"}},"id":"4aac7d82-89bf-4505-811c-b1f6f1b81f64","type":"SaveTool"},{"attributes":{},"id":"bc5ac1a8-b45d-4563-b637-645f981ca382","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ffeac33d-7811-4339-b4b9-559f912ef721","subtype":"Figure","type":"Plot"}},"id":"2698ce02-001c-42f3-9d9a-e7105fbc6b94","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"94062e56-0f40-4bad-b718-eb19e67b21f5","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.03},"x":{"field":"x"},"y":{"field":"y"}},"id":"2710b8b4-56a4-4526-b5e4-d6778ad5be25","type":"Circle"},{"attributes":{},"id":"35ff1618-59aa-4aa7-ae00-c62b412023ce","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.998,1.5,1.175,1.232,1.121,0.988,1.24,1.501,1.225,1.552,0.975,1.121,1.02,1.501,1.664,1.488,1.376,1.5,1.256,1.69,1.82,1.652,1.777,1.504,1.831,1.2],"y":[25.9,29.5,27.9,25.9,29.9,29.9,30.9,28.9,35.9,31.5,31.0,30.9,30.0,28.9,36.9,41.9,40.5,43.9,37.5,37.9,44.5,37.9,38.9,36.9,45.8,41.0]}},"id":"b641cf3e-40fb-4f89-8ea4-b9feb638a954","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"357b9c15-f2e2-4608-a949-cab73902b808","type":"Title"},{"attributes":{"callback":null},"id":"6a466251-7954-4a35-83ed-b10f5a0ae054","type":"DataRange1d"},{"attributes":{"overlay":{"id":"c45e65ce-675c-4dd0-b834-adcb30b44856","type":"BoxAnnotation"},"plot":{"id":"ffeac33d-7811-4339-b4b9-559f912ef721","subtype":"Figure","type":"Plot"}},"id":"fc7b5549-3149-433b-97ea-4bee669f2eca","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"22babf2d-2259-4209-a087-909e0ec0e676","type":"LinearAxis"}],"left":[{"id":"b9e24617-e864-4627-8987-224108e768ad","type":"LinearAxis"}],"plot_height":250,"plot_width":700,"renderers":[{"id":"22babf2d-2259-4209-a087-909e0ec0e676","type":"LinearAxis"},{"id":"4f3c8eee-8d47-40dc-81a7-6639c3350eb6","type":"Grid"},{"id":"b9e24617-e864-4627-8987-224108e768ad","type":"LinearAxis"},{"id":"e948202b-25d4-41ba-8997-1cde5b3fa45f","type":"Grid"},{"id":"c45e65ce-675c-4dd0-b834-adcb30b44856","type":"BoxAnnotation"},{"id":"1febeff6-4316-4aee-804c-479ea0d3d113","type":"GlyphRenderer"},{"id":"ca0e0422-0612-46e9-8b94-8a4eb0517100","type":"GlyphRenderer"}],"title":{"id":"357b9c15-f2e2-4608-a949-cab73902b808","type":"Title"},"tool_events":{"id":"35ff1618-59aa-4aa7-ae00-c62b412023ce","type":"ToolEvents"},"toolbar":{"id":"438a8c28-7e66-4175-9827-304a65c34a65","type":"Toolbar"},"x_range":{"id":"6a466251-7954-4a35-83ed-b10f5a0ae054","type":"DataRange1d"},"x_scale":{"id":"21b90d98-0938-403d-9c04-2038037a9fc7","type":"LinearScale"},"y_range":{"id":"35f3b830-14ea-4e36-b61c-f68ce7a46f15","type":"DataRange1d"},"y_scale":{"id":"162bf3ec-eb18-4e1d-8bb4-f9bf80f50b8c","type":"LinearScale"}},"id":"ffeac33d-7811-4339-b4b9-559f912ef721","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"15c0ac18-5025-42a5-aa47-bfe33 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>
