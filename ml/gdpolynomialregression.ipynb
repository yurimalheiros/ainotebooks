# %% [markdown]
# # Regressão Polinomial Com Descida de Gradiente
#
# Nos notebooks [Regressão Linear Simples com Descida de Gradiente](https://nbviewer.jupyter.org/github/yurimalheiros/ai-notebooks/blob/master/ml/gdlinearregression.ipynb) e [Regressão Linear Múltipla com Descida de Gradiente](https://nbviewer.jupyter.org/github/yurimalheiros/ai-notebooks/blob/master/ml/gdmultiplelinearregression.ipynb) foi mostrado como ajustar funções lineares a um conjunto de dados para realizar previsões.
#
# Em ambos os casos, uma função só se adequava bem aos dados de treinamento se eles seguissem uma tendência linear.
# Entretanto, para dados que não seguiam essa tendência, a função não se adequava bem, o que acabaria gerando previsões ruins. Assim, para dados não lineares é possível ajustar outros tipos de funções que não sejam lineares através da Regressão Polinomial, gerando curvas ou superfícies mais complexas.

# %% [markdown]
# Continuaremos utilizando o exemplo dos preços das casas de acordo com o seu tamanho. Abaixo temos o gráfico representando esses dados.

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
output_notebook()

sizes = [0.998, 1.500, 1.175, 1.232, 1.121, 0.988, 1.240, 1.501, 1.225, 1.552, 0.975, 1.121, 1.020,
        1.501, 1.664, 1.488, 1.376, 1.500, 1.256, 1.690, 1.820, 1.652, 1.777, 1.504, 1.831, 1.200 ]

prices = [25.9, 29.5, 27.9, 25.9, 29.9, 29.9, 30.9, 28.9, 35.9, 31.5, 31.0, 30.9, 30.0, 28.9, 36.9,
          41.9, 40.5, 43.9, 37.5, 37.9, 44.5, 37.9, 38.9, 36.9, 45.8, 41.0]

p = figure(plot_width=700, plot_height=250)
p.circle(sizes, prices)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8aa237ee-6ef4-473f-a3eb-c307565acfdb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eff75cd1-2064-4e25-a37e-2db7b82a8795"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eff75cd1-2064-4e25-a37e-2db7b82a8795");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("0aaeb963-dad2-4fab-ab1a-2c5bc3443e50", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eff75cd1-2064-4e25-a37e-2db7b82a8795");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eff75cd1-2064-4e25-a37e-2db7b82a8795' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"050592fa-4413-42fe-acea-99263e169b06":{"roots":{"references":[{"attributes":{"data_source":{"id":"54b25ed0-6105-4971-bc49-b5e71c8bba26","type":"ColumnDataSource"},"glyph":{"id":"cefb390f-609a-45c3-b2de-196d9a642447","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a887e589-aa7d-4eba-9f37-2def94863028","type":"Circle"},"selection_glyph":null},"id":"d6a57d3f-6d52-439d-b0bb-52005dac3b4c","type":"GlyphRenderer"},{"attributes":{},"id":"40879c7b-77a9-40ca-9ff3-0591d2c2c88a","type":"BasicTicker"},{"attributes":{"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"40879c7b-77a9-40ca-9ff3-0591d2c2c88a","type":"BasicTicker"}},"id":"6512323e-898f-4896-971a-01c329b1ca5e","type":"Grid"},{"attributes":{},"id":"bea74840-2710-40a3-adce-67728ec0a6ba","type":"ToolEvents"},{"attributes":{"formatter":{"id":"bbaa52c1-af01-4cd9-b553-448ab103e48e","type":"BasicTickFormatter"},"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed6853bd-dd7c-45eb-b820-03fd1056e8b4","type":"BasicTicker"}},"id":"33991e14-9f3f-4a67-bd7f-887db5351eac","type":"LinearAxis"},{"attributes":{"callback":null},"id":"fd835bf6-faa6-4f08-9013-25d81b3ad845","type":"DataRange1d"},{"attributes":{},"id":"ed6853bd-dd7c-45eb-b820-03fd1056e8b4","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cefb390f-609a-45c3-b2de-196d9a642447","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed6853bd-dd7c-45eb-b820-03fd1056e8b4","type":"BasicTicker"}},"id":"284764ed-24b8-4c1e-843c-ee341cb3cd97","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a137b9a4-7f2f-40af-a6f6-efee2f169855","type":"PanTool"},{"id":"4a6dd0f2-e444-4ef3-800f-1cadfa8e87a6","type":"WheelZoomTool"},{"id":"8dfc3d9e-d88a-474a-a39c-e9632407b50b","type":"BoxZoomTool"},{"id":"1c4c96b2-d6be-4d86-92f1-1d61d45d1405","type":"SaveTool"},{"id":"c293050e-bee6-4711-95fc-9c9b63133198","type":"ResetTool"},{"id":"8446b8c3-c053-41d3-83fc-9c9bd8e5d532","type":"HelpTool"}]},"id":"50f211d7-c191-4840-94c8-8bcf49f9e74e","type":"Toolbar"},{"attributes":{"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"}},"id":"a137b9a4-7f2f-40af-a6f6-efee2f169855","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"95448bd8-51aa-4b46-b4fd-29768de1abbb","type":"BoxAnnotation"},{"attributes":{},"id":"3488d92e-7bc2-4ec3-839b-96e0ce003b66","type":"LinearScale"},{"attributes":{"callback":null},"id":"24ada199-e623-45fd-81f7-e0d922db6f10","type":"DataRange1d"},{"attributes":{"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"}},"id":"4a6dd0f2-e444-4ef3-800f-1cadfa8e87a6","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"95448bd8-51aa-4b46-b4fd-29768de1abbb","type":"BoxAnnotation"},"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"}},"id":"8dfc3d9e-d88a-474a-a39c-e9632407b50b","type":"BoxZoomTool"},{"attributes":{},"id":"d23cbb38-ef86-40e9-a60c-e5a71a943f8f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"}},"id":"1c4c96b2-d6be-4d86-92f1-1d61d45d1405","type":"SaveTool"},{"attributes":{"plot":{"id":"1aa8354e-b1ce-40af-902c-bd92c818adb6","subtype":"Figure","type":"Plot"}},"id":"c293050e-bee6-4711-95fc-9c9b63133198","type":"ResetTool"},{"attributes":{"callback":null,"column_names ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1]</strong>&gt;</code></p>

# %% [markdown]
# A Regressão Polinomial funciona de maneira muito parecida com a regressão linear, a principal diferença é o tipo da função que é gerada. A regressão linear gera retas ou superfícies representadas por funções do tipo: $f(x) = w_0x_0 + w_1x_1 + ... + x_2x_n$. Por outro lado, a Regressão Polinomial pode gerar curvas e superfícies dos mais variados tipos, por exemplo: $f(x) = w_0x_0 + w_1x_1^2$ ou $f(x) = w_0 + w_1x_1 + w_2x_2^3$.
#
# Vamos fazer um exemplo tentando ajustar uma função do tipo: $f(x) = w_0 + w_1x^2$ aos dados de treinamento.
#
# O código abaixo recebe os valores de x, $w_0$ e $w_1$ e calcula o resultado da função.

# %%
def f(x, w0, w1):
    return w1*(x**2) + w0

# %% [markdown]
# A função de erro médio quadrático continua a mesma. Ela é calculada através do código abaixo:

# %%
def square_error(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)**2

        total += error

    return total/(2*len(X))

# %% [markdown]
# Mais uma vez utilizaremos a descida de gradiente para encontrar a função que melhor se ajusta aos dados de treinamento. Com isso, durante o algoritmo, será necessário calcular as derivadas da função de erro médio quadrático.
#
# O código abaixo calcula a derivada parcial em relação a $w_0$

# %%
def d_error_w0(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)

        total += error

    return total/(len(X))

# %% [markdown]
# E a função abaixo calcula a derivada parcial em relação a $w_1$

# %%
def d_error_w1(X, Y, w0, w1):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1)
        error = (yi - y)

        total += error*x**2

    return total/(len(X))

# %% [markdown]
# Com a função e as derivadas parciais em mãos, aplicaremos o algoritmo de descida de gradiente.
# No código abaixo, os pesos são atualizados 1000 vezes.

# %%
w = [0, 0]
learning_rate = 0.1

for i in range(1000):        
    w0i = w[0] - learning_rate*d_error_w0(sizes, prices, w[0], w[1])
    w1i = w[1] - learning_rate*d_error_w1(sizes, prices, w[0], w[1])

    w[0] = w0i
    w[1] = w1i

print("Função gerada: {} + {}x^2".format(w[0], w[1]))
# Out:
# Função gerada: 24.615774400324003 + 5.070623894139969x^2

# %% [markdown]
# No gráfico a seguir observarmos que a curva encontrada não é mais uma reta.

# %%
import numpy as np

x_points = np.linspace(0.8, 2, 50)
y_points = [f(i, w[0], w[1]) for i in x_points]

p = figure(plot_width=700, plot_height=250)
p.circle(sizes, prices)
p.line(x_points, y_points, line_width=2)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eed5b06e-5c70-4056-b78a-c72e730eff30"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eed5b06e-5c70-4056-b78a-c72e730eff30");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d0e1df65-c0a3-4233-b5bb-485079c0925d", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eed5b06e-5c70-4056-b78a-c72e730eff30");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eed5b06e-5c70-4056-b78a-c72e730eff30' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f7734f98-8e60-4bdf-a68f-0576b180300b":{"roots":{"references":[{"attributes":{"plot":{"id":"ee9aa82b-a8d5-4b0e-a4a4-9df5a7f8e959","subtype":"Figure","type":"Plot"},"ticker":{"id":"15609bfd-3373-4ea8-90e2-882a3d881c15","type":"BasicTicker"}},"id":"0e9d5927-84dd-4d33-951f-f8c8f9a4a6a3","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"5ae34f0b-327d-4a3f-a6ac-feac1637e277","type":"Title"},{"attributes":{"plot":{"id":"ee9aa82b-a8d5-4b0e-a4a4-9df5a7f8e959","subtype":"Figure","type":"Plot"}},"id":"4af1f905-3b0b-45a4-a3d8-88e567cb20ba","type":"WheelZoomTool"},{"attributes":{"below":[{"id":
type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"7ddd3833-2af7-4519-9af1-0eef2b965300","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2c5d4cae-94b7-438a-bcd4-836bc96300c4","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ee9aa82b-a8d5-4b0e-a4a4-9df5a7f ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %% [markdown]
# Vamos fazer um segundo exemplo, agora tentando ajustar a função: $f(x) = w_3x^3 + w_2x^2 + w_1x + w_0$

# %%
def f(x, w0, w1, w2, w3):
    return w3*(x**3) + w2*(x**2) + w1*x + w0

# %% [markdown]
# Nesse exemplo, precisamos calcular quatro derivadas parciais, pois temos 4 coeficientes ($w_0, w_1, w_2, w_3$)

# %%
def d_error_w0(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error

    return total/(len(X))

def d_error_w1(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x

    return total/(len(X))

def d_error_w2(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x**2

    return total/(len(X))

def d_error_w3(X, Y, w0, w1, w2, w3):
    total = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        yi = f(x, w0, w1, w2, w3)
        error = (yi - y)

        total += error*x**3

    return total/(len(X))

# %% [markdown]
# Por fim, realizando a descida de gradiente, encontramos os coeficientes.

# %%
w = [0, 0, 0, 0]
learning_rate = 0.1

for i in range(1000):        
    w0i = w[0] - learning_rate*d_error_w0(sizes, prices, w[0], w[1], w[2], w[3])
    w1i = w[1] - learning_rate*d_error_w1(sizes, prices, w[0], w[1], w[2], w[3])
    w2i = w[2] - learning_rate*d_error_w2(sizes, prices, w[0], w[1], w[2], w[3])
    w3i = w[3] - learning_rate*d_error_w3(sizes, prices, w[0], w[1], w[2], w[3])

    w[0] = w0i
    w[1] = w1i
    w[2] = w2i
    w[3] = w3i
    
print("Função gerada: {} + {}x^2 + {}x^3 + {}x^4".format(w[0], w[1], w[2], w[3]))
# Out:
# Função gerada: 15.796264315235701 + 10.422723031103592x^2 + 3.89992652251128x^3 + -1.1240198966981076x^4

# %%
x_points = np.linspace(0, 3, 50)
y_points = [f(i, w[0], w[1], w[2], w[3]) for i in x_points]

p = figure(plot_width=700, plot_height=250)
p.circle(sizes, prices)
p.line(x_points, y_points, line_width=2)
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ec673388-b109-4942-8ff5-c4993c765e17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ec673388-b109-4942-8ff5-c4993c765e17");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("87722fea-6cb9-40ae-b3ce-f015cd9055ba", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ec673388-b109-4942-8ff5-c4993c765e17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ec673388-b109-4942-8ff5-c4993c765e17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af43500b-24b9-4f7b-94f5-d5b63e585a7c":{"roots":{"references":[{"attributes":{"plot":{"id":"b1927835-88a7-4127-9f51-59764f61da90","subtype":"Figure","type":"Plot"}},"id":"a5a3ea17-1a1e-4227-b630-4b1eefc710f2","type":"ResetTool"},{"attributes":{},"id":"b9a66292-2747-4f93-a979-cf6d1ba0e913","type":"LinearScale"},{"attributes":{"callback":null},"id":"3d86a34a-2b75-4b8c-9a3a-3ef1fcc550d6","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e3fe05f-4e6b-49c5-a4d8-f4b9cb66a545","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"60808e90-dce5-49ea-a2cf-1e95e61ed0d7","type":"Circle"},{"attributes":{},"id":"76f8fcc8-132e-4148-a89b-253337edde10","type":"ToolEvents"},{"attributes":{"data_source":{"id":"3c0ae52d-07dc-46c4-b343-7f2f1bfcbdb5","type":"ColumnDataSource"},"glyph":{"id":"1c6b19d8-3f17-4e42-970d-2edc666078bb","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":